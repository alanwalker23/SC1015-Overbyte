# %% [markdown]
# # KMeans Clustering
# ### Taking in consideration of only Numerical Data Types

# %%
# Basic Libraries
#!pip install kmodes
#!pip install sklearn
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
from sklearn.cluster import KMeans

sb.set() # set the default Seaborn style for graphics

# %%
student_por = pd.read_csv('student-por.csv',sep=';')
student_por.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean    16.744222    2.514638    2.306626    1.568567    1.930663    0.221880
# std      1.218138    1.134552    1.099931    0.748660    0.829510    0.593235
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    1.000000    1.000000    1.000000    0.000000
# 50%     17.000000    2.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  649.000000  649.000000  649.000000  649.000000  649.000000  649.000000
# mean     3.930663    3.180277    3.184900    1.502311    2.280431    3.536210
# std      0.955717    1.051093    1.175766    0.924834    1.284380    1.446259
# min      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
# 25%      4.000000    3.000000    2.000000    1.000000    1.000000    2.000000
# 50%      4.000000    3.000000    3.000000    1.000000    2.000000    4.000000
# 75%      5.000000    4.000000    4.000000    2.000000    3.000000    5.000000
# max      5.000000    5.000000    5.000000    5.000000    5.000000    5.000000
#
#          absences          G1          G2          G3
# count  649.000000  649.000000  649.000000  649.000000
# mean     3.659476   11.399076   11.570108   11.906009
# std      4.640759    2.745265    2.913639    3.230656
# min      0.000000    0.000000    0.000000    0.000000
# 25%      0.000000   10.000000   10.000000   10.000000
# 50%      2.000000   11.000000   11.000000   12.000000
# 75%      6.000000   13.000000   13.000000   14.000000
# max     32.000000   19.000000   19.000000   19.000000

# %%
for x in range(0,32):    
    col1 = student_por. iloc[:, x]
    print(student_por.columns.values[x])
    print(col1.value_counts())
# Out:
# school
# GP    423
# MS    226
# Name: school, dtype: int64
# sex
# F    383
# M    266
# Name: sex, dtype: int64
# age
# 17    179
# 16    177
# 18    140
# 15    112
# 19     32
# 20      6
# 21      2
# 22      1
# Name: age, dtype: int64
# address
# U    452
# R    197
# Name: address, dtype: int64
# famsize
# GT3    457
# LE3    192
# Name: famsize, dtype: int64
# Pstatus
# T    569
# A     80
# Name: Pstatus, dtype: int64
# Medu
# 2    186
# 4    175
# 1    143
# 3    139
# 0      6
# Name: Medu, dtype: int64
# Fedu
# 2    209
# 1    174
# 3    131
# 4    128
# 0      7
# Name: Fedu, dtype: int64
# Mjob
# other       258
# services    136
# at_home     135
# teacher      72
# health       48
# Name: Mjob, dtype: int64
# Fjob
# other       367
# services    181
# at_home      42
# teacher      36
# health       23
# Name: Fjob, dtype: int64
# reason
# course        285
# home          149
# reputation    143
# other          72
# Name: reason, dtype: int64
# guardian
# mother    455
# father    153
# other      41
# Name: guardian, dtype: int64
# traveltime
# 1    366
# 2    213
# 3     54
# 4     16
# Name: traveltime, dtype: int64
# studytime
# 2    305
# 1    212
# 3     97
# 4     35
# Name: studytime, dtype: int64
# failures
# 0    549
# 1     70
# 2     16
# 3     14
# Name: failures, dtype: int64
# schoolsup
# no     581
# yes     68
# Name: schoolsup, dtype: int64
# famsup
# yes    398
# no     251
# Name: famsup, dtype: int64
# paid
# no     610
# yes     39
# Name: paid, dtype: int64
# activities
# no     334
# yes    315
# Name: activities, dtype: int64
# nursery
# yes    521
# no     128
# Name: nursery, dtype: int64
# higher
# yes    580
# no      69
# Name: higher, dtype: int64
# internet
# yes    498
# no     151
# Name: internet, dtype: int64
# romantic
# no     410
# yes    239
# Name: romantic, dtype: int64
# famrel
# 4    317
# 5    180
# 3    101
# 2     29
# 1     22
# Name: famrel, dtype: int64
# freetime
# 3    251
# 4    178
# 2    107
# 5     68
# 1     45
# Name: freetime, dtype: int64
# goout
# 3    205
# 2    145
# 4    141
# 5    110
# 1     48
# Name: goout, dtype: int64
# Dalc
# 1    451
# 2    121
# 3     43
# 5     17
# 4     17
# Name: Dalc, dtype: int64
# Walc
# 1    247
# 2    150
# 3    120
# 4     87
# 5     45
# Name: Walc, dtype: int64
# health
# 5    249
# 3    124
# 4    108
# 1     90
# 2     78
# Name: health, dtype: int64
# absences
# 0     244
# 2     110
# 4      93
# 6      49
# 8      42
# 10     21
# 1      12
# 12     12
# 5      12
# 16     10
# 14      8
# 9       7
# 3       7
# 11      5
# 18      3
# 7       3
# 21      2
# 15      2
# 22      2
# 30      1
# 26      1
# 24      1
# 13      1
# 32      1
# Name: absences, dtype: int64
# G1
# 10    95
# 11    91
# 12    82
# 13    72
# 14    71
# 9     65
# 8     42
# 15    35
# 7     33
# 16    22
# 17    16
# 6      9
# 18     7
# 5      5
# 4      2
# 0      1
# 19     1
# Name: G1, dtype: int64
# G2
# 11    103
# 12     86
# 10     83
# 13     80
# 9      72
# 14     54
# 8      40
# 15     38
# 16     25
# 17     20
# 7      16
# 18     14
# 6       7
# 0       7
# 5       3
# 19      1
# Name: G2, dtype: int64

# %%
student_por.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
# dtypes: int64(16), object(17)
# memory usage: 167.4+ KB

# %%
student_por['age'] = student_por['age'].astype(float)
student_por['failures'] = student_por['failures'].astype(float)
student_por['absences'] = student_por['absences'].astype(float)
student_por['G1'] = student_por['G1'].astype(float)
student_por['G2'] = student_por['G2'].astype(float)
student_por['G3'] = student_por['G3'].astype(float)
student_por.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    float64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    float64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    int64
#  24  freetime    649 non-null    int64
#  25  goout       649 non-null    int64
#  26  Dalc        649 non-null    int64
#  27  Walc        649 non-null    int64
#  28  health      649 non-null    int64
#  29  absences    649 non-null    float64
#  30  G1          649 non-null    float64
#  31  G2          649 non-null    float64
#  32  G3          649 non-null    float64
# dtypes: float64(6), int64(10), object(17)
# memory usage: 167.4+ KB

# %% [markdown]
# ### Selected Variables are as follows

# %%
selected = student_por[['age','failures','absences','G1','G2','G3']]
selected
# Out:
#       age  failures  absences    G1    G2    G3
# 0    18.0       0.0       4.0   0.0  11.0  11.0
# 1    17.0       0.0       2.0   9.0  11.0  11.0
# 2    15.0       0.0       6.0  12.0  13.0  12.0
# 3    15.0       0.0       0.0  14.0  14.0  14.0
# 4    16.0       0.0       0.0  11.0  13.0  13.0
# ..    ...       ...       ...   ...   ...   ...
# 644  19.0       1.0       4.0  10.0  11.0  10.0
# 645  18.0       0.0       4.0  15.0  15.0  16.0
# 646  18.0       0.0       6.0  11.0  12.0   9.0
# 647  17.0       0.0       6.0  10.0  10.0  10.0
# 648  18.0       0.0       4.0  10.0  11.0  11.0
#
# [649 rows x 6 columns]

# %% [markdown]
# # Performing Elbow Plot to obtain recommended number of clusters
# When the slope is more gentle, information gain becomes constant and we choose optimal number of clusters before this happens

# %%
wcss=[]
for i in range(1,7):
    kmeans = KMeans(i)
    kmeans.fit(selected)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

number_clusters = range(1,7)
plt.plot(number_clusters,wcss)
plt.title('Elbow Plot of Student_Por [Kmeans]')
plt.xlabel('Number of clusters')
plt.ylabel('Score [WCSS]')
# Out:
# C:\Users\alanw\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# Text(0, 0.5, 'Score [WCSS]')

# %%
kmeans = KMeans(n_clusters=3, init='k-means++', max_iter=300, n_init=10, random_state=0)
pred_y = kmeans.fit_predict(selected)

# %%
pred_y
student_por['cluster'] = list(pred_y)

# %%
colors = ['#DF2020', '#81DF20', '#2095DF'] #Red, green, blue
student_por['c'] = student_por.cluster.map({0:colors[0], 1:colors[1], 2:colors[2]})

# %%
fig = plt.figure(figsize=(26,6))
ax = fig.add_subplot(131, projection='3d')
ax.scatter(student_por.G1, student_por.G2, student_por.G3, c=student_por.c, s=15)
ax.set_xlabel('G1')
ax.set_ylabel('G2')
ax.set_zlabel('G3')
plt.show()

# %% [markdown]
# # As seen from plot above
# Red has a cluster size of 261
# Green has a cluster size of 286
# Blue has a cluster size of 102
# Red has the smallest mean score for G1 to G3
# Green has the highest mean score for G1 to G3
# Blue is balanced between both clusters

# %%
plt.scatter(student_por.G1, student_por.G3, c=student_por.c, alpha = 0.6, s=10)

# %%
plt.scatter(student_por.G2, student_por.G3, c=student_por.c, alpha = 0.6, s=10)

# %%
catdf = pd.read_csv('student-por.csv',sep=';')
catdf['Medu'] = student_por['Medu'].astype(object)
catdf['Fedu'] = student_por['Fedu'].astype(object)
catdf['traveltime'] = student_por['traveltime'].astype(object)
catdf['studytime'] = student_por['studytime'].astype(object)
catdf['famrel'] = student_por['famrel'].astype(object)
catdf['freetime'] = student_por['freetime'].astype(object)
catdf['goout'] = student_por['goout'].astype(object)
catdf['Dalc'] = student_por['Dalc'].astype(object)
catdf['Walc'] = student_por['Walc'].astype(object)
catdf['health'] = student_por['health'].astype(object)
catdf['cluster'] = student_por['cluster'].astype(object)
catdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    object
#  7   Fedu        649 non-null    object
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    object
#  13  studytime   649 non-null    object
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
#  19  nursery     649 non-null    object
#  20  higher      649 non-null    object
#  21  internet    649 non-null    object
#  22  romantic    649 non-null    object
#  23  famrel      649 non-null    object
#  24  freetime    649 non-null    object
#  25  goout       649 non-null    object
#  26  Dalc        649 non-null    object
#  27  Walc        649 non-null    object
#  28  health      649 non-null    object
#  29  absences    649 non-null    int64
#  30  G1          649 non-null    int64
#  31  G2          649 non-null    int64
#  32  G3          649 non-null    int64
#  33  cluster     649 non-null    object
# dtypes: int64(6), object(28)
# memory usage: 172.5+ KB

# %%
cluster1 = catdf[student_por['cluster'] == 0]
cluster2 = catdf[student_por['cluster'] == 1]
cluster3 = catdf[student_por['cluster'] == 2]

# %%
print(cluster1.shape)
print(cluster2.shape)
print(cluster3.shape)
# Out:
# (261, 34)
# (286, 34)
# (102, 34)

# %%
def checkpercent(columnname):
    frame = pd.crosstab(index=columnname, columns='count')
    #health = health['count']
    frame['index'] = frame.index
    total = sum(frame['count'])
    percentages = []
    for i in (frame.index):
        percentages.append(frame['count'][i]/total*100)
    frame['percent'] = percentages
    print(frame)

# %%
for i in student_por:
    #if(student_por[i])
    print(i)
    checkpercent(cluster1[i])
    checkpercent(cluster2[i])
    checkpercent(cluster3[i])
    print()
    print()
    print()
# Out:
# school
# col_0   count index    percent
# school
# GP        128    GP  49.042146
# MS        133    MS  50.957854
# col_0   count index    percent
# school
# GP        218    GP  76.223776
# MS         68    MS  23.776224
# col_0   count index    percent
# school
# GP         77    GP  75.490196
# MS         25    MS  24.509804
#
#
#
# sex
# col_0  count index    percent
# sex
# F        138     F  52.873563
# M        123     M  47.126437
# col_0  count index    percent
# sex
# F        187     F  65.384615
# M         99     M  34.615385
# col_0  count index    percent
# sex
# F         58     F  56.862745
# M         44     M  43.137255
#
#
#
# age
# col_0  count  index    percent
# age
# 15        47     15  18.007663
# 16        76     16  29.118774
# 17        67     17  25.670498
# 18        48     18  18.390805
# 19        21     19   8.045977
# 20         1     20   0.383142
# 21         1     21   0.383142
# col_0  count  index    percent
# age
# 15        55     15  19.230769
# 16        87     16  30.419580
# 17        77     17  26.923077
# 18        61     18  21.328671
# 19         4     19   1.398601
# 20         2     20   0.699301
# col_0  count  index    percent
# age
# 15        10     15   9.803922
# 16        14     16  13.725490
# 17        35     17  34.313725
# 18        31     18  30.392157
# 19         7     19   6.862745
# 20         3     20   2.941176
# 21         1     21   0.980392
# 22         1     22   0.980392
#
#
#
# address
# col_0    count index   percent
# address
# R          108     R  41.37931
# U          153     U  58.62069
# col_0    count index    percent
# address
# R           64     R  22.377622
# U          222     U  77.622378
# col_0    count index    percent
# address
# R           25     R  24.509804
# U           77     U  75.490196
#
#
#
# famsize
# col_0    count index    percent
# famsize
# GT3        182   GT3  69.731801
# LE3         79   LE3  30.268199
# col_0    count index   percent
# famsize
# GT3        199   GT3  69.58042
# LE3         87   LE3  30.41958
# col_0    count index    percent
# famsize
# GT3         76   GT3  74.509804
# LE3         26   LE3  25.490196
#
#
#
# Pstatus
# col_0    count index    percent
# Pstatus
# A           28     A  10.727969
# T          233     T  89.272031
# col_0    count index    percent
# Pstatus
# A           33     A  11.538462
# T          253     T  88.461538
# col_0    count index    percent
# Pstatus
# A           19     A  18.627451
# T           83     T  81.372549
#
#
#
# Medu
# col_0  count  index    percent
# Medu
# 0          5      0   1.915709
# 1         77      1  29.501916
# 2         80      2  30.651341
# 3         51      3  19.540230
# 4         48      4  18.390805
# col_0  count  index    percent
# Medu
# 0          1      0   0.349650
# 1         43      1  15.034965
# 2         73      2  25.524476
# 3         58      3  20.279720
# 4        111      4  38.811189
# col_0  count  index    percent
# Medu
# 1         23      1  22.549020
# 2         33      2  32.352941
# 3         30      3  29.411765
# 4         16      4  15.686275
#
#
#
# Fedu
# col_0  count  index    percent
# Fedu
# 0          5      0   1.915709
# 1         88      1  33.716475
# 2         87      2  33.333333
# 3         44      3  16.858238
# 4         37      4  14.176245
# col_0  count  index    percent
# Fedu
# 0          2      0   0.699301
# 1         57      1  19.930070
# 2         89      2  31.118881
# 3         63      3  22.027972
# 4         75      4  26.223776
# col_0  count  index    percent
# Fedu
# 1         29      1  28.431373
# 2         33      2  32.352941
# 3         24      3  23.529412
# 4         16      4  15.686275
#
#
#
# Mjob
# col_0     count     index    percent
# Mjob
# at_home      78   at_home  29.885057
# health       16    health   6.130268
# other        95     other  36.398467
# services     50  services  19.157088
# teacher      22   teacher   8.429119
# col_0     count     index    percent
# Mjob
# at_home      37   at_home  12.937063
# health       29    health  10.139860
# other       116     other  40.559441
# services     60  services  20.979021
# teacher      44   teacher  15.384615
# col_0     count     index    percent
# Mjob
# at_home      20   at_home  19.607843
# health        3    health   2.941176
# other        47     other  46.078431
# services     26  services  25.490196
# teacher       6   teacher   5.882353
#
#
#
# Fjob
# col_0     count     index    percent
# Fjob
# at_home      19   at_home   7.279693
# health       10    health   3.831418
# other       146     other  55.938697
# services     78  services  29.885057
# teacher       8   teacher   3.065134
# col_0     count     index    percent
# Fjob
# at_home      15   at_home   5.244755
# health       11    health   3.846154
# other       161     other  56.293706
# services     73  services  25.524476
# teacher      26   teacher   9.090909
# col_0     count     index    percent
# Fjob
# at_home       8   at_home   7.843137
# health        2    health   1.960784
# other        60     other  58.823529
# services     30  services  29.411765
# teacher       2   teacher   1.960784
#
#
#
# reason
# col_0       count       index    percent
# reason
# course        137      course  52.490421
# home           43        home  16.475096
# other          38       other  14.559387
# reputation     43  reputation  16.475096
# col_0       count       index    percent
# reason
# course        107      course  37.412587
# home           74        home  25.874126
# other          25       other   8.741259
# reputation     80  reputation  27.972028
# col_0       count       index    percent
# reason
# course         41      course  40.196078
# home           32        home  31.372549
# other           9       other   8.823529
# reputation     20  reputation  19.607843
#
#
#
# guardian
# col_0     count   index    percent
# guardian
# father       59  father  22.605364
# mother      186  mother  71.264368
# other        16   other   6.130268
# col_0     count   index    percent
# guardian
# father       77  father  26.923077
# mother      199  mother  69.580420
# other        10   other   3.496503
# col_0     count   index    percent
# guardian
# father       17  father  16.666667
# mother       70  mother  68.627451
# other        15   other  14.705882
#
#
#
# traveltime
# col_0       count  index    percent
# traveltime
# 1             126      1  48.275862
# 2              96      2  36.781609
# 3              29      3  11.111111
# 4              10      4   3.831418
# col_0       count  index    percent
# traveltime
# 1             184      1  64.335664
# 2              81      2  28.321678
# 3              18      3   6.293706
# 4               3      4   1.048951
# col_0       count  index    percent
# traveltime
# 1              56      1  54.901961
# 2              36      2  35.294118
# 3               7      3   6.862745
# 4               3      4   2.941176
#
#
#
# studytime
# col_0      count  index    percent
# studytime
# 1            112      1  42.911877
# 2            109      2  41.762452
# 3             26      3   9.961686
# 4             14      4   5.363985
# col_0      count  index    percent
# studytime
# 1             59      1  20.629371
# 2            147      2  51.398601
# 3             61      3  21.328671
# 4             19      4   6.643357
# col_0      count  index    percent
# studytime
# 1             41      1  40.196078
# 2             49      2  48.039216
# 3             10      3   9.803922
# 4              2      4   1.960784
#
#
#
# failures
# col_0     count  index    percent
# failures
# 0           195      0  74.712644
# 1            44      1  16.858238
# 2            13      2   4.980843
# 3             9      3   3.448276
# col_0     count  index    percent
# failures
# 0           282      0  98.601399
# 1             3      1   1.048951
# 2             1      2   0.349650
# col_0     count  index    percent
# failures
# 0            72      0  70.588235
# 1            23      1  22.549020
# 2             2      2   1.960784
# 3             5      3   4.901961
#
#
#
# schoolsup
# col_0      count index    percent
# schoolsup
# no           228    no  87.356322
# yes           33   yes  12.643678
# col_0      count index   percent
# schoolsup
# no           258    no  90.20979
# yes           28   yes   9.79021
# col_0      count index    percent
# schoolsup
# no            95    no  93.137255
# yes            7   yes   6.862745
#
#
#
# famsup
# col_0   count index    percent
# famsup
# no        109    no  41.762452
# yes       152   yes  58.237548
# col_0   count index    percent
# famsup
# no        108    no  37.762238
# yes       178   yes  62.237762
# col_0   count index    percent
# famsup
# no         34    no  33.333333
# yes        68   yes  66.666667
#
#
#
# paid
# col_0  count index    percent
# paid
# no       239    no  91.570881
# yes       22   yes   8.429119
# col_0  count index    percent
# paid
# no       273    no  95.454545
# yes       13   yes   4.545455
# col_0  count index    percent
# paid
# no        98    no  96.078431
# yes        4   yes   3.921569
#
#
#
# activities
# col_0       count index    percent
# activities
# no            147    no  56.321839
# yes           114   yes  43.678161
# col_0       count index    percent
# activities
# no            131    no  45.804196
# yes           155   yes  54.195804
# col_0       count index    percent
# activities
# no             56    no  54.901961
# yes            46   yes  45.098039
#
#
#
# nursery
# col_0    count index    percent
# nursery
# no          56    no  21.455939
# yes        205   yes  78.544061
# col_0    count index    percent
# nursery
# no          50    no  17.482517
# yes        236   yes  82.517483
# col_0    count index    percent
# nursery
# no          22    no  21.568627
# yes         80   yes  78.431373
#
#
#
# higher
# col_0   count index    percent
# higher
# no         43    no  16.475096
# yes       218   yes  83.524904
# col_0   count index    percent
# higher
# no          2    no   0.699301
# yes       284   yes  99.300699
# col_0   count index    percent
# higher
# no         24    no  23.529412
# yes        78   yes  76.470588
#
#
#
# internet
# col_0     count index   percent
# internet
# no           85    no  32.56705
# yes         176   yes  67.43295
# col_0     count index    percent
# internet
# no           50    no  17.482517
# yes         236   yes  82.517483
# col_0     count index    percent
# internet
# no           16    no  15.686275
# yes          86   yes  84.313725
#
#
#
# romantic
# col_0     count index    percent
# romantic
# no          164    no  62.835249
# yes          97   yes  37.164751
# col_0     count index    percent
# romantic
# no          190    no  66.433566
# yes          96   yes  33.566434
# col_0     count index    percent
# romantic
# no           56    no  54.901961
# yes          46   yes  45.098039
#
#
#
# famrel
# col_0   count  index    percent
# famrel
# 1          11      1   4.214559
# 2          12      2   4.597701
# 3          46      3  17.624521
# 4         116      4  44.444444
# 5          76      5  29.118774
# col_0   count  index    percent
# famrel
# 1           5      1   1.748252
# 2          11      2   3.846154
# 3          34      3  11.888112
# 4         157      4  54.895105
# 5          79      5  27.622378
# col_0   count  index    percent
# famrel
# 1           6      1   5.882353
# 2           6      2   5.882353
# 3          21      3  20.588235
# 4          44      4  43.137255
# 5          25      5  24.509804
#
#
#
# freetime
# col_0     count  index    percent
# freetime
# 1            19      1   7.279693
# 2            41      2  15.708812
# 3            91      3  34.865900
# 4            75      4  28.735632
# 5            35      5  13.409962
# col_0     count  index    percent
# freetime
# 1            17      1   5.944056
# 2            52      2  18.181818
# 3           118      3  41.258741
# 4            76      4  26.573427
# 5            23      5   8.041958
# col_0     count  index    percent
# freetime
# 1             9      1   8.823529
# 2            14      2  13.725490
# 3            42      3  41.176471
# 4            27      4  26.470588
# 5            10      5   9.803922
#
#
#
# goout
# col_0  count  index    percent
# goout
# 1         25      1   9.578544
# 2         53      2  20.306513
# 3         80      3  30.651341
# 4         50      4  19.157088
# 5         53      5  20.306513
# col_0  count  index    percent
# goout
# 1         17      1   5.944056
# 2         75      2  26.223776
# 3        100      3  34.965035
# 4         58      4  20.279720
# 5         36      5  12.587413
# col_0  count  index    percent
# goout
# 1          6      1   5.882353
# 2         17      2  16.666667
# 3         25      3  24.509804
# 4         33      4  32.352941
# 5         21      5  20.588235
#
#
#
# Dalc
# col_0  count  index    percent
# Dalc
# 1        172      1  65.900383
# 2         51      2  19.540230
# 3         23      3   8.812261
# 4         10      4   3.831418
# 5          5      5   1.915709
# col_0  count  index    percent
# Dalc
# 1        229      1  80.069930
# 2         45      2  15.734266
# 3          8      3   2.797203
# 4          2      4   0.699301
# 5          2      5   0.699301
# col_0  count  index    percent
# Dalc
# 1         50      1  49.019608
# 2         25      2  24.509804
# 3         12      3  11.764706
# 4          5      4   4.901961
# 5         10      5   9.803922
#
#
#
# Walc
# col_0  count  index    percent
# Walc
# 1         95      1  36.398467
# 2         56      2  21.455939
# 3         44      3  16.858238
# 4         43      4  16.475096
# 5         23      5   8.812261
# col_0  count  index    percent
# Walc
# 1        129      1  45.104895
# 2         71      2  24.825175
# 3         56      3  19.580420
# 4         22      4   7.692308
# 5          8      5   2.797203
# col_0  count  index    percent
# Walc
# 1         23      1  22.549020
# 2         23      2  22.549020
# 3         20      3  19.607843
# 4         22      4  21.568627
# 5         14      5  13.725490
#
#
#
# health
# col_0   count  index    percent
# health
# 1          22      1   8.429119
# 2          33      2  12.643678
# 3          51      3  19.540230
# 4          37      4  14.176245
# 5         118      5  45.210728
# col_0   count  index    percent
# health
# 1          51      1  17.832168
# 2          37      2  12.937063
# 3          52      3  18.181818
# 4          55      4  19.230769
# 5          91      5  31.818182
# col_0   count  index    percent
# health
# 1          17      1  16.666667
# 2           8      2   7.843137
# 3          21      3  20.588235
# 4          16      4  15.686275
# 5          40      5  39.215686
#
#
#
# absences
# col_0     count  index    percent
# absences
# 0           105      0  40.229885
# 1             6      1   2.298851
# 2            56      2  21.455939
# 3             5      3   1.915709
# 4            55      4  21.072797
# 5             8      5   3.065134
# 6            24      6   9.195402
# 7             1      7   0.383142
# 8             1      8   0.383142
# col_0     count  index    percent
# absences
# 0           139      0  48.601399
# 1             6      1   2.097902
# 2            54      2  18.881119
# 3             2      3   0.699301
# 4            38      4  13.286713
# 5             4      5   1.398601
# 6            25      6   8.741259
# 7             2      7   0.699301
# 8            11      8   3.846154
# 9             1      9   0.349650
# 10            4     10   1.398601
# col_0     count  index    percent
# absences
# 8            30      8  29.411765
# 9             6      9   5.882353
# 10           17     10  16.666667
# 11            5     11   4.901961
# 12           12     12  11.764706
# 13            1     13   0.980392
# 14            8     14   7.843137
# 15            2     15   1.960784
# 16           10     16   9.803922
# 18            3     18   2.941176
# 21            2     21   1.960784
# 22            2     22   1.960784
# 24            1     24   0.980392
# 26            1     26   0.980392
# 30            1     30   0.980392
# 32            1     32   0.980392
#
#
#
# G1
# col_0  count  index    percent
# G1
# 0          1      0   0.383142
# 4          1      4   0.383142
# 5          5      5   1.915709
# 6          8      6   3.065134
# 7         24      7   9.195402
# 8         29      8  11.111111
# 9         51      9  19.540230
# 10        66     10  25.287356
# 11        57     11  21.839080
# 12        16     12   6.130268
# 13         3     13   1.149425
# col_0  count  index    percent
# G1
# 10         5     10   1.748252
# 11        20     11   6.993007
# 12        50     12  17.482517
# 13        63     13  22.027972
# 14        69     14  24.125874
# 15        33     15  11.538462
# 16        22     16   7.692308
# 17        16     17   5.594406
# 18         7     18   2.447552
# 19         1     19   0.349650
# col_0  count  index    percent
# G1
# 4          1      4   0.980392
# 6          1      6   0.980392
# 7          9      7   8.823529
# 8         13      8  12.745098
# 9         14      9  13.725490
# 10        24     10  23.529412
# 11        14     11  13.725490
# 12        16     12  15.686275
# 13         6     13   5.882353
# 14         2     14   1.960784
# 15         2     15   1.960784
#
#
#
# G2
# col_0  count  index    percent
# G2
# 0          7      0   2.681992
# 5          2      5   0.766284
# 6          7      6   2.681992
# 7         10      7   3.831418
# 8         28      8  10.727969
# 9         53      9  20.306513
# 10        63     10  24.137931
# 11        76     11  29.118774
# 12        14     12   5.363985
# 13         1     13   0.383142
# col_0  count  index    percent
# G2
# 10         2     10   0.699301
# 11         3     11   1.048951
# 12        63     12  22.027972
# 13        70     13  24.475524
# 14        52     14  18.181818
# 15        36     15  12.587413
# 16        25     16   8.741259
# 17        20     17   6.993007
# 18        14     18   4.895105
# 19         1     19   0.349650
# col_0  count  index    percent
# G2
# 5          1      5   0.980392
# 7          6      7   5.882353
# 8         12      8  11.764706
# 9         19      9  18.627451
# 10        18     10  17.647059
# 11        24     11  23.529412
# 12         9     12   8.823529
# 13         9     13   8.823529
# 14         2     14   1.960784
# 15         2     15   1.960784
#
#
#
# G3
# col_0  count  index    percent
# G3
# 0         15      0   5.747126
# 1          1      1   0.383142
# 6          2      6   0.766284
# 7          6      7   2.298851
# 8         23      8   8.812261
# 9         27      9  10.344828
# 10        70     10  26.819923
# 11        82     11  31.417625
# 12        31     12  11.877395
# 13         4     13   1.532567
# col_0  count  index    percent
# G3
# 10         1     10   0.349650
# 12        29     12  10.139860
# 13        76     13  26.573427
# 14        53     14  18.531469
# 15        47     15  16.433566
# 16        35     16  12.237762
# 17        28     17   9.790210
# 18        15     18   5.244755
# 19         2     19   0.699301
# col_0  count  index    percent
# G3
# 5          1      5   0.980392
# 6          1      6   0.980392
# 7          4      7   3.921569
# 8         12      8  11.764706
# 9          8      9   7.843137
# 10        26     10  25.490196
# 11        22     11  21.568627
# 12        12     12  11.764706
# 13         2     13   1.960784
# 14        10     14   9.803922
# 15         2     15   1.960784
# 16         1     16   0.980392
# 17         1     17   0.980392
#
#
#
# cluster
# col_0    count  index  percent
# cluster
# 0          261      0    100.0
# col_0    count  index  percent
# cluster
# 1          286      1    100.0
# col_0    count  index  percent
# cluster
# 2          102      2    100.0
#
#
#
# c
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'c'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9912/3758848044.py in <module>
#       2     #if(student_por[i])
#       3     print(i)
# ----> 4     checkpercent(cluster1[i])
#       5     checkpercent(cluster2[i])
#       6     checkpercent(cluster3[i])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'c'

# %%
def percent(columnname):
    df = pd.DataFrame()
    frame = pd.crosstab(index=columnname, columns='count')
    #health = health['count']
    frame['index'] = frame.index
    total = sum(frame['count'])
    percentages = []
    for i in (frame.index):
        percentages.append(frame['count'][i]/total*100)
    frame['percent'] = percentages
    df['Variables'] = frame['index']
    df['Percentages'] = frame['percent']
    return df

# %%
def plot (varname):
    fig, axs = plt.subplots(1, 3, figsize=(20, 5))
    axs[0].set_ylim([0,100])
    axs[1].set_ylim([0,100])
    axs[2].set_ylim([0,100])
    newdf1 = pd.DataFrame()
    newdf2 = pd.DataFrame()
    newdf3 = pd.DataFrame()
    newdf1 = percent(cluster1[varname])
    newdf2 = percent(cluster2[varname])
    newdf3 = percent(cluster3[varname])
    axs[0].set_xlim([1,len(newdf1.iloc[:,0].value_counts())])
    axs[1].set_xlim([1,len(newdf2.iloc[:,0].value_counts())])
    axs[2].set_xlim([1,len(newdf3.iloc[:,0].value_counts())])
    axs[0].set_title('Cluster 1 - {size} entries'.format(size = len(cluster1)))
    axs[1].set_title('Cluster 2 - {size} entries'.format(size = len(cluster2)))
    axs[2].set_title('Cluster 3 - {size} entries'.format(size = len(cluster3)))
    newdf1[['Percentages']].plot(ax=axs[0], kind='bar')
    newdf2[['Percentages']].plot(ax=axs[1], kind='bar')
    newdf3[['Percentages']].plot(ax=axs[2], kind='bar')

# %% [markdown]
# ## Focused Plots that show the prominent variable based on the percentage
# Plots are for those variables not detected to have high correlation in previous analysis

# %%
plot('Mjob')

# %%
plot('absences')
